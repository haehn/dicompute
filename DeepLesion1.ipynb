# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import DICOMPUTE as D

# %%
bbox = np.array([203.747, 195.458, 295.598, 310.164])
im_small, box, scale = D.DeepLesion.get_lesion('004382_01_01_306.png', bbox)
imshow(im_small)

# %%
bbox = np.array([317.283, 359.578, 347.317, 386.274])
im_small, box, scale = D.DeepLesion.get_lesion('004409_01_01_008.png', bbox)
imshow(im_small)

# %%
bbox = np.array([260.519, 228.554, 315.009, 265.362])
im_small, box, scale = D.DeepLesion.get_lesion('004411_01_01_006.png', bbox)
imshow(im_small)
