# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataset as d

# %%
ld = d.LesionDataset()

# %%
img, bbox, scale = ld[20]

# %%
imshow(img, cmap='gray')

# %%
# create set of training images

# %%
# create set of testing images

# %%
# train the autoencoder and see how well the latent space allows to reconstruct the original image
