# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
a = pd.read_csv('DL_info.csv')

# %%
DATADIR = '/home/haehn/Data/Images_png/'

# %%
import DICOMPUTE as D

# %%
for f, b in zip(a.File_name, a.Bounding_boxes):
    try:
        bbox = np.array([float(v) for v in b.split(',')])
        D.DeepLesion.get_lesion(f, bbox=bbox, datadir=DATADIR, show=False)
    except Exception as e:
        print(e)
        print(f)
# Out:
# 'NoneType' object has no attribute 'copy'
# 001064_01_01_200.png
# 'NoneType' object has no attribute 'copy'
# 001096_04_02_170.png
# 'NoneType' object has no attribute 'copy'
# 002084_01_02_259.png

# %%
bbox = np.array([203.747, 195.458, 295.598, 310.164])
im_small, box, scale = D.DeepLesion.get_lesion('004382_01_01_306.png', bbox, datadir=DATADIR)
imshow(im_small)

# %%
im_small.shape
# Out:
# (120, 120)

# %%
bbox = np.array([317.283, 359.578, 347.317, 386.274])
im_small, box, scale = D.DeepLesion.get_lesion('004409_01_01_008.png', bbox, datadir=DATADIR)
imshow(im_small)

# %%
D.DeepLesion.showType(3, datadir=DATADIR, show=True)

# %%
bbox = np.array([260.519, 228.554, 315.009, 265.362])
im_small, box, scale = D.DeepLesion.get_lesion('004411_01_01_006.png', bbox, datadir=DATADIR)
imshow(im_small)

# %%
bbox = np.array([260.519, 228.554, 315.009, 265.362])
im_small, box, scale = D.DeepLesion.get_lesion('000001_03_01_088.png', bbox, datadir=DATADIR)
imshow(im_small)

# %%
img, bbox, scale = D.DeepLesion.showType(3, datadir=DATADIR, show=False)

# %%
imshow(img)
